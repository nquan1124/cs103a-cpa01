# %% [markdown]
# # Analysis of Hate Crimes in America

# %% [markdown]
# Questions:
# What are the most violent counties in New York State?

# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv ('data/Crimes.csv')
df.describe()
# Out:
#             Year    Population    Index Count    Index Rate  Violent Count  \
# count  1922.0000  1.922000e+03    1922.000000   1922.000000    1922.000000
# mean   2005.0000  3.066055e+05    9465.393340   2421.576899    1719.240895
# std       8.9466  5.188130e+05   21528.041721   1269.635269    5413.099266
# min    1990.0000  4.342000e+03      29.000000    277.800000       1.000000
# 25%    1997.0000  5.163125e+04    1013.500000   1667.050000      90.000000
# 50%    2005.0000  9.045400e+04    2011.000000   2221.050000     175.000000
# 75%    2013.0000  2.348018e+05    6359.500000   2865.075000     663.000000
# max    2020.0000  2.646816e+06  217786.000000  19317.300000   63087.000000
#
#        Violent Rate  Property Count  Property Rate  Firearm Rate
# count   1922.000000     1922.000000    1922.000000   1847.000000
# mean     278.618991     7746.152445    2142.957908     34.106930
# std      293.523486    16535.903467    1065.769964     82.414042
# ...

# %%
output = df.pivot_table(index=['Year'],
                       columns = ['County'],
                       values = ['Violent Count'])
output
# Out:
#        Violent Count                                                         \
# County        Albany Allegany    Bronx Broome Cattaraugus Cayuga Chautauqua
# Year
# 1990          1524.0    146.0  33635.0  306.0       171.0  196.0      229.0
# 1991          1674.0    134.0  33515.0  339.0       273.0  216.0      227.0
# 1992          1588.0    161.0  31050.0  365.0       322.0  210.0      296.0
# 1993          1669.0    131.0  31235.0  389.0       291.0  205.0      395.0
# 1994          1771.0    129.0  27863.0  437.0       279.0  186.0      450.0
# 1995          1606.0    160.0  24660.0  420.0       279.0  233.0      399.0
# 1996          1408.0     93.0  20615.0  424.0       251.0  163.0      341.0
# 1997          1450.0     84.0  19592.0  383.0       231.0  168.0      398.0
# 1998          1310.0     69.0  18391.0  386.0       154.0  178.0      390.0
# 1999          1133.0     94.0  16820.0  386.0       176.0  179.0      311.0
# ...

# %%
output.plot(title='Violent Rates in NY State Counties from 1990-2020')
# Out:
# <AxesSubplot:title={'center':'Violent Rates in NY State Counties from 1990-2020'}, xlabel='Year'>

# %%
test = df.groupby('Violent Count')
test.first()
# Out:
#                  County  Year  Population  Index Count  Index Rate  \
# Violent Count
# 1              Hamilton  1998      5224.0          101      1933.4
# 2              Hamilton  1992      5315.0          146      2746.9
# 3              Hamilton  1995      5228.0          151      2888.3
# 4              Hamilton  1990      5279.0          100      1894.3
# 5              Hamilton  1994      5395.0          111      2057.5
# ...                 ...   ...         ...          ...         ...
# 48212             Kings  1994   2303574.0       148398      6442.1
# 54931             Kings  1993   2307039.0       169236      7335.6
# 56682             Kings  1992   2315780.0       176699      7630.2
# 60814             Kings  1991   2307907.0       191259      8287.1
# 63087             Kings  1990   2299285.0       202009      8785.7
#
#                Violent Rate  Property Count  Property Rate Firearm Count  \
# Violent Count
# ...

# %%
test = df.groupby(['Firearm Rate','Violent Rate'])
test.last()
# Out:
#                              County  Year  Population  Index Count  \
# Firearm Rate Violent Rate
# 0.0          19.1          Hamilton  1998      5224.0          101
#              20.6          Hamilton  2011      4858.0           58
#              20.8          Hamilton  2012      4819.0           81
#              21.0          Hamilton  2014      4766.0           62
#              32.6            Seneca  2010     33740.0          198
# ...                             ...   ...         ...          ...
# 905.1        2800.8           Bronx  1990   1200900.0       104729
# 906.5        2780.4           Bronx  1991   1205404.0       100071
# 909.8        2447.6           Kings  1992   2315780.0       176699
# 914.4        2743.8           Kings  1990   2299285.0       202009
# 948.0        2635.0           Kings  1991   2307907.0       191259
#
#                            Index Rate  Violent Count  Property Count  \
# Firearm Rate Violent Rate
# ...
